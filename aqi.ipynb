# %%
import requests
import pandas as pd
import json

# %%
api_url1 = "https://api.openaq.org/v2/measurements"
# api_url1 = "https://api.openaq.org/v2/locations"
# api_url1 = "https://api.openaq.org/v2/parameters"
# api_url1 = "https://api.openaq.org/v2/sources"

response = requests.get(api_url1)

# %%
response_text = response.text
json_path = 'measurements.json'

# %%
with open(json_path, 'w') as json_file:
    # Write the response JSON to the file
    json.dump(response_text, json_file, indent=4)

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df= pd.read_csv('response.csv')
#       2 df.head()
#
# File c:\Users\shouv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\shouv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
print(response.json())
# Out:
# {'detail': 'Connection timed out'}

# %% [markdown]
# Displaying AQI data by county. 2021

# %%
data=pd.read_csv("annual_aqi_by_county_2021.csv")
data.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2021            280        264             16
# 1  Alabama     Clay  2021            110        101              9
# 2  Alabama   DeKalb  2021            361        331             30
# 3  Alabama   Elmore  2021            241        238              3
# 4  Alabama   Etowah  2021            286        253             33
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
data.describe()
# Out:
#          Year  Days with AQI    Good Days  Moderate Days  \
# count  1002.0    1002.000000  1002.000000    1002.000000
# mean   2021.0     325.237525   261.518962      58.525948
# std       0.0      74.587962    70.426290      45.320876
# min    2021.0       7.000000     7.000000       0.000000
# 25%    2021.0     336.250000   227.000000      23.000000
# 50%    2021.0     362.000000   279.000000      49.000000
# 75%    2021.0     365.000000   313.000000      83.750000
# max    2021.0     365.000000   364.000000     258.000000
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# count                          1002.000000     1002.000000
# mean                              3.820359        1.148703
# std                               9.099718        4.533023
# min                               0.000000        0.000000
# 25%                               0.000000        0.000000
# 50%                               1.000000        0.000000
# ...

# %%
c_data=pd.read_csv("annual_conc_by_monitor_2021.csv")
c_data.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           88101    1  30.497478
#
#    Longitude  Datum            Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                     Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  PM2.5 - Local Conditions                  24 HOUR  ...
#
#   75th Percentile 50th Percentile 10th Percentile    Local Site Name  \
# ...
